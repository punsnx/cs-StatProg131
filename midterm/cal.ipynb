# %%
import numpy as np
import pandas as pd
from scipy import stats
import statistics
from math import perm, comb

# %%
scores = pd.read_csv("~/Desktop/CSV/mid113_lab_scores.csv")
scores.head()
# Out:
#      รหัส  กิจกรรม-ckw 5  กิจกรรม - usa 5  เข้าปฏิบัติการ 15  \
# 0  6H7RN7           2.79                0                NaN
# 1  WFONDT           3.83                0                NaN
# 2  FKLJB/           3.83                0                NaN
# 3  SSNWY4           2.68                0                NaN
# 4  GSFNNN           3.83                0                NaN
#
#    สอบปฏิบัติ Mid 10  สอบปฏิบัติ Final 10  Midterm (raw) 150  \
# 0                6.3                  NaN                NaN
# 1                6.7                  NaN                NaN
# 2                5.0                  NaN                NaN
# 3                3.8                  NaN                NaN
# 4                3.8                  NaN                NaN
#
#     คะแนนมิดเทอม 25  คะแนนไฟนอล 30  Total 100
# 0               NaN            NaN        9.0
# 1               NaN            NaN       10.5
# 2               NaN            NaN        8.8
# ...

# %%
scores.filter(["รหัส","สอบปฏิบัติ Mid 10"])[scores["สอบปฏิบัติ Mid 10"]>=9]
# Out:
#        รหัส  สอบปฏิบัติ Mid 10
# 18   GF8BOL               12.0
# 45   7YMCYO                9.0
# 63   CL68VB                9.2
# 68   RTSNWT                9.2
# 91   LXONA6                9.2
# 122  LKBTRW               12.0
# 123  MNU3Y4                9.7
